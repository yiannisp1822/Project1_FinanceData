# %%
import pandas as pd
import datetime as dt
from prophet import Prophet

# %matplotlib inline

# %%
gdp_df = pd.read_csv("./Resources/GDP.csv", index_col='DATE', parse_dates=True)
display(gdp_df.shape)
gdp_df.head()
# Out:
# (311, 1)
#                 GDP
# DATE
# 1947-01-01  243.164
# 1947-04-01  245.968
# 1947-07-01  249.585
# 1947-10-01  259.745
# 1948-01-01  265.742

# %%
gdp_df.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fedfunds_df = pd.read_csv("./Resources/FEDFUNDS.csv", index_col='DATE', parse_dates=True)
display(fedfunds_df.shape)
fedfunds_df.head()
# Out:
# (844, 1)
#             FEDFUNDS
# DATE
# 1954-07-01      0.80
# 1954-08-01      1.22
# 1954-09-01      1.07
# 1954-10-01      0.85
# 1954-11-01      0.83

# %%
fedfunds_df.plot()
# Out:
# <Axes: xlabel='DATE'>
